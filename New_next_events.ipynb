# %% [markdown]
# # DATAFRAME WITH EVENT NAME AND DATE

# %%
##import libraries request and bs4
import requests #library needed for requesting permission to website
from bs4 import BeautifulSoup #needed for filtering through website html code
import pandas as pd

# %%
thislist1 = []
thislist2 = []

for i in range(0,2):
    s = str(i)
    url = "https://www.hetdepot.be/programma?page=" + s
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    groups = soup.select('div.calendar__group')
    for group in groups:
        date = group.select_one('h3').text.strip()
        items = group.select('div.calendar-item')
        for item in items:
            title = item.select_one('h2.calendar-item__title').text.strip()
            thislist1.append(title)
            thislist2.append(date)

# %%
df = pd.DataFrame(thislist1)
df.columns = ["Event Name"]
df['Date'] = thislist2
df
# Out:
#                                             Event Name  \
# 0    Belpop Bonanza Leuven                         ...
# 1    Belpop Bonanza Leuven                         ...
# 2                     Depot Café presents Porcelain id
# 3                                                K.ZIA
# 4    Johannes Is Zijn Naam                         ...
# ..                                                 ...
# 114               M-IDZOMER FOR KIDS: Kapitein Winokio
# 115  M-IDZOMER 2023: DAAN + Calicos + Pitou + Zimme...
# 116  M-IDZOMER 2023: Suzanne Vega + Alela Diane + K...
# 117  Jean-Marie Aerts                             \...
# 118                 Scott Bradlee's Postmodern Jukebox
#
#                                               Date
# 0                               vrijdag05 mei 2023
# 1                              zaterdag06 mei 2023
# 2                               maandag08 mei 2023
# 3                               dinsdag09 mei 2023
# 4                              woensdag10 mei 2023
# ..                                             ...
# 114  zaterdag29 jul 2023\ntot\nzaterdag29 jul 2023
# 115  zaterdag29 jul 2023\ntot\nzaterdag29 jul 2023
# 116      zondag30 jul 2023\ntot\nzondag30 jul 2023
# 117                             vrijdag15 sep 2023
# 118                            zaterdag16 sep 2023
#
# [119 rows x 2 columns]
