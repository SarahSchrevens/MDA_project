# %%
import pandas as pd

# %%
files = ["df_01.csv", "df_02.csv", "df_03.csv", "df_04.csv", "df_05.csv", "df_06.csv", "df_07.csv", "df_08.csv", "df_09.csv" ]

# %%
merged_data = pd.DataFrame()

# %%
dfs = []

# %%
for file in files:
    df = pd.read_csv(file)
    dfs.append(df)

# %%
merged_data = pd.concat(dfs, ignore_index=True)
merged_data.head()
# Out:
#                   date         day         time  start_hour  weekday  \
# 0  2022-03-01 00:00:00  2022-03-01  00:00-01:00           0  Tuesday
# 1  2022-03-01 01:00:00  2022-03-01  01:00-02:00           1  Tuesday
# 2  2022-03-01 02:00:00  2022-03-01  02:00-03:00           2  Tuesday
# 3  2022-03-01 03:00:00  2022-03-01  03:00-04:00           3  Tuesday
# 4  2022-03-01 04:00:00  2022-03-01  04:00-05:00           4  Tuesday
#
#    LC_HUMIDITY  LC_RAININ  LC_TEMP_QCL3_list  school  loko  depot   location  \
# 0    79.722222        0.0           1.932109     1.0   1.0    0.0  Number 35
# 1    78.809524        0.0           1.732657     1.0   1.0    0.0  Number 35
# 2    77.738095        0.0           1.727462     1.0   1.0    0.0  Number 35
# 3    76.714286        0.0           1.934884     1.0   1.0    0.0  Number 35
# 4    79.023810        0.0           1.647822     1.0   1.0    0.0  Number 35
#
#     Latitude  Longitude  laf50_per_hour   baseline  noisiness
# ...

# %%
merged_data.tail()
# Out:
#                       date         day         time  start_hour   weekday  \
# 65659  2022-12-31 19:00:00  2022-12-31  19:00-20:00          19  Saturday
# 65660  2022-12-31 20:00:00  2022-12-31  20:00-21:00          20  Saturday
# 65661  2022-12-31 21:00:00  2022-12-31  21:00-22:00          21  Saturday
# 65662  2022-12-31 22:00:00  2022-12-31  22:00-23:00          22  Saturday
# 65663  2022-12-31 23:00:00  2022-12-31  23:00-24:00          23  Saturday
#
#        LC_HUMIDITY  LC_RAININ  LC_TEMP_QCL3_list  school  loko  depot  \
# 65659    61.357143        0.0          15.681402     1.0   0.0    0.0
# 65660    57.952381        0.0          15.955844     1.0   0.0    0.0
# 65661    56.500000        0.0          16.187194     1.0   0.0    0.0
# 65662    56.261905        0.0          16.059805     1.0   0.0    0.0
# 65663    54.976190        0.0          16.136172     1.0   0.0    0.0
#
#        location   Latitude  Longitude  laf50_per_hour   baseline  noisiness
# ...

# %%
merged_data.to_csv('mergeddf01_df09.csv', index=False)
