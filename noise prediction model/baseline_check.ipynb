# %% [markdown]
# the task is simple. compare the noise data for several groups. the aim is to create a baseline, and the baselines will differ based on several possible categories. that being said, what categories actually make sense will depend on some experimentation from the group's point of view.
#
# the first task: group the weather and noise aggregate data based on the 7 days of the week, and use visual comparison to check if the noise levels overlap with each other.

# %%
import pandas as pd

# %%
#load the data
dfs = []
# Loop through the filenames and read the dataframes
for i in range(1, 10):
    filename = f"df_{i:02d}.csv"  # Format the filename with leading zeros
    filepath = f"/Users/stefbp/Documents/GitHub/MDA_project/noise prediction model/Past Data matrix/{filename}"
    df = pd.read_csv(filepath)
    dfs.append(df)
df = pd.concat(dfs, ignore_index=True)
df[['date', 'day']] = df[['date', 'day']].apply(lambda x: pd.to_datetime(x)) #reading it from the raw file returns string dtypes for the time variables.
#variable time is left untouched.

# %%
#dataframes based on the day of the week. have to create extra variable: night (20.00-06.00) or day (otherwise)
df['hour'] = df['date'].dt.hour
df['night'] = df['hour'].apply(lambda x: 1 if x >= 20 or x < 6 else 0)

# %%
df.tail(3)
# Out:
#                      date        day         time   weekday  LC_HUMIDITY
# 78837 2022-12-31 21:00:00 2022-12-31  21:00-22:00  Saturday    56.261905  \
# 78838 2022-12-31 22:00:00 2022-12-31  22:00-23:00  Saturday    54.976190
# 78839 2022-12-31 23:00:00 2022-12-31  23:00-24:00  Saturday    52.452381
#
#        LC_RAININ  LC_TEMP_QCL3_list  school  loko  depot  location   Latitude
# 78837        0.0          16.059805     1.0   0.0    0.0  Vrijthof  50.878748  \
# 78838        0.0          16.136172     1.0   0.0    0.0  Vrijthof  50.878748
# 78839        0.0          16.415485     1.0   0.0    0.0  Vrijthof  50.878748
#
#        Longitude  laf50_per_hour  hour  night
# 78837   4.701134            45.6    21      1
# 78838   4.701134            53.9    22      1
# 78839   4.701134            57.5    23      1

# %%
locs = df.location.unique()
locs
# Out:
# array(['Number 35', 'Number 57', 'Number 62',
#        'Number 76 ("His & Hears” Hair salon in Leuven)',
#        'Calvarie Chapel (near the Faculty of Economics)',
#        'Corner of the Parkstraat & Naamse straat', 'Number 81',
#        'Kiosk Stadspark', 'Vrijthof'], dtype=object)

# %%
import plotly.express as px
loc = locs[8]
naam = df[df['location']==loc]
fig = px.line(naam,x='date',y='laf50_per_hour',
              title='Naamsestraat ' + loc + ' Noise')
fig.update_traces(opacity=.4)
naam_night = naam[naam['night']==1];naam_day = naam[naam['night']==0]
fig.add_scatter(x=naam_night['date'],y=naam_night['laf50_per_hour'],
                mode="markers",marker=dict(size=5, color="red"))

fig.show()

# %%
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

fig = make_subplots(rows=3, cols=3)

['Number 35', 'Number 57', 'Number 62',
       'Number 76 ("His & Hears” Hair salon in Leuven)',
       'Calvarie Chapel (near the Faculty of Economics)',
       'Corner of the Parkstraat & Naamse straat', 'Number 81',
       'Kiosk Stadspark', 'Vrijthof']
loc = locs[8]
naam_35 = df[df['location']=='Number 35']
naam_57 = df[df['location']=='Number 57']
naam_62 = df[df['location']=='Number 62']
naam_76 = df[df['location']=='Number 76 ("His & Hears” Hair salon in Leuven)']
naam_pn = df[df['location']=='Corner of the Parkstraat & Naamse straat']
naam_81 = df[df['location']=='Number 81']
naam_ks = df[df['location']=='Kiosk Stadspark']
naam_vr = df[df['location']=='Vrijthof']

fig.update_traces(opacity=.4)
# Add a line plot to the first subplot
fig.add_trace(go.Scatter(x=naam_35['date'], y=naam_35['laf50_per_hour'], mode='lines'), row=1, col=1)
naam=naam_35;naam_night = naam[naam['night']==1];naam_day = naam[naam['night']==0]
fig.add_scatter(x=naam_night['date'],y=naam_night['laf50_per_hour'],
                mode="markers",marker=dict(size=5, color="red"))

# Show the grid of plots
fig.show()

# %% [markdown]
# At first the goal was to make a 3x3 grid but seeing Naamsestraat 35 alone, i dont feel like it's worth pursuing further.
# what of weekday/weekend?

# %%
import plotly.express as px
loc = locs[8]
naam = df[df['location']==loc]
fig = px.line(naam,x='date',y='laf50_per_hour',
              title= loc + ' Noise')
fig.update_traces(opacity=.4)
we = naam['weekday'].isin(['Saturday', 'Sunday'])
naam_wd = naam[naam[we==1]];naam_we = naam[naam[we==0]]
fig.add_scatter(x=naam_night['date'],y=naam_night['laf50_per_hour'],
                mode="markers",marker=dict(size=5, color="red"))

fig.show()
