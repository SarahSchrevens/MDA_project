# %% [markdown]
# # DATAFRAME WITH EVENT NAME AND DATE

# %%
##import libraries request and bs4
import requests #library needed for requesting permission to website
from bs4 import BeautifulSoup #needed for filtering through website html code
import pandas as pd

# %%
thislist1 = []
thislist2 = []

for i in range(0,11): #first 11 pages
    s = str(i)
    url = "https://www.hetdepot.be/archief?page=" + s
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    groups = soup.select('div.calendar__group')
    for group in groups:
        date = group.select_one('h3').text.strip() #get date
        items = group.select('div.calendar-item') #get title
        for item in items:
            title = item.select_one('h2.calendar-item__title').text.strip()
            thislist1.append(title)
            thislist2.append(date)

# %%
df_past = pd.DataFrame(thislist1)
df_past.columns = ["Event Name"]
df_past['Date'] = thislist2
df_past
# Out:
#                                             Event Name                  Date
# 0                                                K.ZIA    dinsdag09 mei 2023
# 1                     Depot Café presents Porcelain id    maandag08 mei 2023
# 2    Belpop Bonanza Leuven                         ...   zaterdag06 mei 2023
# 3    Belpop Bonanza Leuven                         ...    vrijdag05 mei 2023
# 4    RAUW!                             \n          ...  donderdag04 mei 2023
# ..                                                 ...                   ...
# 325  Leuven Air presents Les Negresses Vertes + \n ...   zaterdag17 jul 2021
# 326  Leuven Air presents Froukje + Yong Yello  + \n...  donderdag15 jul 2021
# 327  Leuven Air presents Milow + \n          Wanthanee    vrijdag09 jul 2021
# 328  Leuven Air presents Absynthe Minded + \n      ...  donderdag08 jul 2021
# 329  Leuven Air presents Yevgueni + \n          Tom...  donderdag01 jul 2021
#
# [330 rows x 2 columns]

# %% [markdown]
# # Format 'date' column

# %%
#create dataframe only date
df_only_date = df_past.loc[:, ["Date"]]
df_only_date
# Out:
#                      Date
# 0      dinsdag09 mei 2023
# 1      maandag08 mei 2023
# 2     zaterdag06 mei 2023
# 3      vrijdag05 mei 2023
# 4    donderdag04 mei 2023
# ..                    ...
# 325   zaterdag17 jul 2021
# 326  donderdag15 jul 2021
# 327    vrijdag09 jul 2021
# 328  donderdag08 jul 2021
# 329  donderdag01 jul 2021
#
# [330 rows x 1 columns]

# %%
list1 = []
list2 = []

for i in range(len(df_only_date)):
    ser = df_only_date.loc[i]
    series = ser.to_string()
    all_words = str.split(series)
    if len(all_words) == 4:
        #extract second word of each row
        second_word = all_words[1]
        #split word
        last_two = second_word[-2:]
        rest = second_word[:-2]
        result = rest + " " + last_two 
        #replace
        words = result.split() #split first word
        words[0] = "" #first word replaced with empty space
        new_string = " ".join(words) #adding rest to empty space to get only number
        #get rest of the words
        month = all_words[2] #get third word
        month = str(month) 
        year = all_words[3] #get fourth word
        year = str(year)
        final = year + month + new_string #put together
        new_final = f"{year} {month} {new_string}" #format
        new_final = new_final.replace("jan", "01")
        new_final = new_final.replace('feb', '02')
        new_final = new_final.replace('mrt', '03')
        new_final = new_final.replace('apr', '04')
        new_final = new_final.replace('mei', '05')
        new_final = new_final.replace('jun', '06')
        new_final = new_final.replace('jul', '07')
        new_final = new_final.replace('aug', '08')
        new_final = new_final.replace('sep', '09')
        new_final = new_final.replace('okt', '10')
        new_final = new_final.replace('nov', '11')
        new_final = new_final.replace('dec', '12')
        new_final = new_final.replace('  ', ' ')
        new_final = new_final.replace(' ', '-')
        list1.append(new_final)
    else:
        list1.append(new_final)
    if len(all_words) == 6:
        #extract fourth word of each row
        fourth_word = all_words[3]
        #keep only last 2 characters
        last_two_2 = fourth_word[-2:]
        str(last_two)
        #get rest of the words
        month2 = all_words[4] #get fifth word
        month2 = str(month) 
        year2 = all_words[5] #get sixth word
        year2 = str(year)
        final2 = year2 + month2 + last_two_2 #put together
        new_final2 = f"{year2} {month2} {last_two_2}" #format
        new_final2 = new_final2.replace("jan", "01")
        new_final2 = new_final2.replace('feb', '02')
        new_final2 = new_final2.replace('mrt', '03')
        new_final2 = new_final2.replace('apr', '04')
        new_final2 = new_final2.replace('mei', '05')
        new_final2 = new_final2.replace('jun', '06')
        new_final2 = new_final2.replace('jul', '07')
        new_final2 = new_final2.replace('aug', '08')
        new_final2 = new_final2.replace('sep', '09')
        new_final2 = new_final2.replace('okt', '10')
        new_final2 = new_final2.replace('nov', '11')
        new_final2 = new_final2.replace('dec', '12')
        new_final2 = new_final2.replace('  ', ' ')
        new_final2 = new_final2.replace(' ', '-')
        list2.append(new_final2)
    else:
        list2.append(new_final)

# %% [markdown]
# # Create final DataFrame

# %%
df_past = pd.DataFrame(thislist1)
df_past.columns = ["Event Name"]
df_past["StartDate"] = list1
df_past["EndDate"] = list2
df_past
# Out:
#                                             Event Name   StartDate     EndDate
# 0                                                K.ZIA  2023-05-09  2023-05-09
# 1                     Depot Café presents Porcelain id  2023-05-08  2023-05-08
# 2    Belpop Bonanza Leuven                         ...  2023-05-06  2023-05-06
# 3    Belpop Bonanza Leuven                         ...  2023-05-05  2023-05-05
# 4    RAUW!                             \n          ...  2023-05-04  2023-05-04
# ..                                                 ...         ...         ...
# 325  Leuven Air presents Les Negresses Vertes + \n ...  2021-07-17  2021-07-17
# 326  Leuven Air presents Froukje + Yong Yello  + \n...  2021-07-15  2021-07-15
# 327  Leuven Air presents Milow + \n          Wanthanee  2021-07-09  2021-07-09
# 328  Leuven Air presents Absynthe Minded + \n      ...  2021-07-08  2021-07-08
# 329  Leuven Air presents Yevgueni + \n          Tom...  2021-07-01  2021-07-01
#
# [330 rows x 3 columns]

# %%
#manual modifications
df_past.loc[82, "StartDate"] = "2022-07-28"
df_past.loc[82, "EndDate"] = "2022-07-31"
df_past.loc[173, "StartDate"] = "2022-02-01"

# %%
df_past = df_past[df_past["StartDate"].str[:4] == "2022"]
df_past = df_past.reset_index(drop=True)
df_past[50:100]
# Out:
#                                            Event Name   StartDate     EndDate
# 50         Gabriel Ríos + \n          Camille Camille  2022-10-24  2022-10-24
# 51                                       Walter Trout  2022-10-22  2022-10-22
# 52  COOL presents Alfa Mist  + \n          Adja + ...  2022-10-21  2022-10-21
# 53                                The Dream Syndicate  2022-10-20  2022-10-20
# 54     Midge Ure + \n          India Electric Company  2022-10-19  2022-10-19
# 55                Het Depot & INUIT present overdrive  2022-10-18  2022-10-18
# 56  mxmtoon + \n          Ricky Montgomery\n      ...  2022-10-17  2022-10-17
# 57                Angel Olsen + \n          Tomberlin  2022-10-15  2022-10-15
# 58  Studio STUK x Het Depot: Loverman curates Dida...  2022-10-13  2022-10-13
# 59  Heather Nova + \n          Jonathan Frith\n   ...  2022-10-10  2022-10-10
# 60  Levellers  + \n          Nick Parker & The Fal...  2022-10-09  2022-10-09
# 61                   Mudhoney + \n          The Drove  2022-10-08  2022-10-08
# 62                                        Dub Unit #2  2022-10-08  2022-10-08
# 63                                  Wim Mertens Winds  2022-10-06  2022-10-06
# 64                                           Open Mic  2022-10-05  2022-10-05
# 65  Madeleine Peyroux                             ...  2022-10-04  2022-10-04
# 66  COOL presents Femi Kuti + \n          Camilla ...  2022-10-02  2022-10-02
# 67  Henny, een reggae saluut door Rootsriders met ...  2022-10-01  2022-10-01
# 68  Studio STUK x Het Depot: M I M I curates Aho S...  2022-10-01  2022-10-01
# 69             Jeremy Loops + \n          Casey Lowry  2022-09-30  2022-09-30
# 70                              COOL presents Lettuce  2022-09-29  2022-09-29
# 71                              45Toeren preselection  2022-09-29  2022-09-29
# 72  The Stranglers + \n          Sovjet War (sold ...  2022-09-28  2022-09-28
# 73  Motorpsycho + Ufomammut + Monkey3 & meer ihkv ...  2022-09-28  2022-09-24
# 74  De Kreuners                              \n   ...  2022-09-22  2022-09-22
# 75  De Kreuners                             \n    ...  2022-09-21  2022-09-21
# 76  Welcome to Night Vale: The Haunting of Night V...  2022-09-17  2022-09-17
# 77                         COOL presents Jaga Jazzist  2022-09-15  2022-09-15
# 78       The Sheila Divine  + \n          Korinthians  2022-09-11  2022-09-11
# 79                   Go_A + \n          Nona Problemo  2022-09-09  2022-09-09
# 80  Clouseau                             \n       ...  2022-09-07  2022-09-07
# 81  Clouseau                             \n       ...  2022-09-06  2022-09-06
# 82                                     M-IDZOMER 2022  2022-09-06  2022-09-31
# 83                                Doganov + Anzahlung  2022-06-25  2022-06-25
# 84                 Depot Café presents Rare Americans  2022-06-21  2022-06-21
# 85  Suzanne Vega                             \n   ...  2022-06-20  2022-06-20
# 86                                            Niveau4  2022-06-16  2022-06-16
# 87                                        Frazey Ford  2022-06-12  2022-06-12
# 88           Donder, Hel & Hagel + \n          Kregel  2022-06-11  2022-06-11
# 89                                     House of Cohen  2022-06-10  2022-06-10
# 90                    Taxiwars  + \n          Tristan  2022-06-09  2022-06-09
# 91                                         Starsailor  2022-06-06  2022-06-06
# 92  Discobar Galaxie's Nightshift                 ...  2022-06-06  2022-06-06
# 93                                      Rick De Leeuw  2022-06-04  2022-06-04
# 94                                          Jim White  2022-06-03  2022-06-03
# 95                                            Buurman  2022-06-01  2022-06-01
# 96  JJ Wilde                             \n       ...  2022-05-30  2022-05-30
# 97                                    Nick Waterhouse  2022-05-28  2022-05-28
# 98  Van der Graaf Generator                       ...  2022-05-25  2022-05-25
# 99  Chuck Phophet                              \n ...  2022-05-24  2022-05-24

# %%
#csv
df_past.to_csv('past_events.csv', index=False)
