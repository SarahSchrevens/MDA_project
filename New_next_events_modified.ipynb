# %%
##import libraries request and bs4
import requests #library needed for requesting permission to website
from bs4 import BeautifulSoup #needed for filtering through website html code
import pandas as pd

# %%
thislist1 = []
thislist2 = []

url = "https://www.hetdepot.be/programma?page=" + "1"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

groups = soup.select('div.calendar__group')
for group in groups:
    date = group.select_one('h3').text.strip()
    items = group.select('div.calendar-item')
    for item in items:
        title = item.select_one('h2.calendar-item__title').text.strip()
        thislist1.append(title)
        thislist2.append(date)

# %%
thislist1
# Out:
# ['Half Moon Run + \n          Flyte\n      \n          (nieuwe datum)',
#  'Sunn O))) + \n          Aluk Todolo',
#  'Patrick Watson                             \n          (nieuwe datum)',
#  'Patrick Watson                             \n          (nieuwe datum)',
#  'Maaike Ouboter',
#  'COOL presents Theo Katzman',
#  'Frank Boeijen',
#  'Jazz Brak',
#  'JP Cooper',
#  'Black Box Revelation',
#  'Coely',
#  'Elder + \n          Slomosa',
#  'Lloyd Cole',
#  'Portland',
#  'Peter Hook & The Light',
#  'Lieven Scheire                             \n          (sold out)',
#  'Lieven Scheire                             \n          (sold out)',
#  'Danko Jones',
#  'Luka Bloom',
#  'Warhaus                             \n          (sold out)',
#  'Warhaus                             \n          (extra concert)',
#  'Ramkot',
#  'Ramkot',
#  'Spinvis',
#  'Axelle Red: A Very Special Christmas',
#  'Kim Wilde                             \n          (sold out)',
#  'Lieven Scheire                             \n          (extra show)',
#  'Lieven Scheire                             \n          (extra show)',
#  'Stef Bos',
#  'Belpop Bonanza Leuven                             \n          (extra show) (sold out)',
#  'Belpop Bonanza Leuven                             \n          (sold out)',
#  'Depot Café presents Porcelain id',
#  'K.ZIA',
#  'Johannes Is Zijn Naam                             \n          (sold out)',
#  'Metejoor                             \n          (sold out)',
#  'Metejoor                             \n          (extra concert) (sold out)',
#  'Millie Manders & The Shutup                             \n          (geannuleerd)',
#  'Discobar Galaxie                             \n          (sold out)',
#  'Tangerine Dream',
#  'DAAN                             \n          (sold out)',
#  'Natalia                             \n          (sold out)',
#  'PSYCHONAUT + \n          Doodseskader',
#  'Jonas Winterland',
#  'Jef Neve',
#  'BLØF                             \n          (sold out)',
#  'Amber Run + \n          Myles Smith',
#  'Lady Linn + \n          Her Magnificent Seven',
#  'Depot Café presents PM Warson',
#  'COOL presents Curtis Harding',
#  'YES                             \n          (nieuwe datum) (laatste tickets)',
#  'The Man Up North',
#  'FOKOFPOLISIEKAR',
#  'M-IDZOMER 2023: José González + Marble Sounds + Sam De Nef',
#  'M-IDZOMER 2023: Thurston Moore Group + King Hannah + Dans Dans + Dienne',
#  'M-IDZOMER FOR KIDS: Kapitein Winokio',
#  'M-IDZOMER 2023: DAAN + Calicos + Pitou + Zimmerman plays Wish You Were',
#  'M-IDZOMER 2023: Suzanne Vega + Alela Diane + Kids With Buns + Loverman',
#  'Jean-Marie Aerts                             \n          (nieuwe datum)',
#  "Scott Bradlee's Postmodern Jukebox"]

# %%
df = pd.DataFrame(thislist1)
df.columns = ["Event Name"]
df['Date'] = thislist2
df
# Out:
#                                            Event Name  \
# 0   Half Moon Run + \n          Flyte\n      \n   ...
# 1                 Sunn O))) + \n          Aluk Todolo
# 2   Patrick Watson                             \n ...
# 3   Patrick Watson                             \n ...
# 4                                      Maaike Ouboter
# 5                          COOL presents Theo Katzman
# 6                                       Frank Boeijen
# 7                                           Jazz Brak
# 8                                           JP Cooper
# 9                                Black Box Revelation
# 10                                              Coely
# 11                        Elder + \n          Slomosa
# 12                                         Lloyd Cole
# 13                                           Portland
# 14                             Peter Hook & The Light
# 15  Lieven Scheire                             \n ...
# 16  Lieven Scheire                             \n ...
# 17                                        Danko Jones
# 18                                         Luka Bloom
# 19  Warhaus                             \n        ...
# 20  Warhaus                             \n        ...
